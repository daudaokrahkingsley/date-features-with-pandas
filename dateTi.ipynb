# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_csv('online_retail_IIa.csv')
df
# Out:
#        Invoice StockCode                          Description  Quantity  \
# 0       536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1       536365     71053                  WHITE METAL LANTERN         6
# 2       536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3       536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4       536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
# ...        ...       ...                                  ...       ...
# 541905  581587     22899         CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254        CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255      CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138        BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                              POSTAGE         1
#
#              InvoiceDate  Price  Customer ID         Country
# ...

# %%
df['InvoiceDate'].dtype
# Out:
# dtype('O')

# %%
df['InvoiceDate']
# Out:
# 0          01/12/2010 8:26
# 1          01/12/2010 8:26
# 2          01/12/2010 8:26
# 3          01/12/2010 8:26
# 4          01/12/2010 8:26
#                 ...
# 541905    09/12/2011 12:50
# 541906    09/12/2011 12:50
# 541907    09/12/2011 12:50
# 541908    09/12/2011 12:50
# 541909    09/12/2011 12:50
# Name: InvoiceDate, Length: 541910, dtype: object

# %%
df.InvoiceDate.str.slice(-5,-3).astype(int).head()
# Out:
# 0    8
# 1    8
# 2    8
# 3    8
# 4    8
# Name: InvoiceDate, dtype: int32

# %%
df['InvoiceDate'] = pd.to_datetime(df.InvoiceDate)
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  Price  Customer ID         Country
# 0 2010-01-12 08:26:00   2.55      17850.0  United Kingdom
# 1 2010-01-12 08:26:00   3.39      17850.0  United Kingdom
# 2 2010-01-12 08:26:00   2.75      17850.0  United Kingdom
# 3 2010-01-12 08:26:00   3.39      17850.0  United Kingdom
# 4 2010-01-12 08:26:00   3.39      17850.0  United Kingdom

# %%
df.dtypes
# Out:
# Invoice                object
# StockCode              object
# Description            object
# Quantity                int64
# InvoiceDate    datetime64[ns]
# Price                 float64
# Customer ID           float64
# Country                object
# dtype: object

# %%
df.tail()
# Out:
#        Invoice StockCode                      Description  Quantity  \
# 541905  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                          POSTAGE         1
#
#                InvoiceDate  Price  Customer ID Country
# 541905 2011-09-12 12:50:00   2.10      12680.0  France
# 541906 2011-09-12 12:50:00   4.15      12680.0  France
# 541907 2011-09-12 12:50:00   4.15      12680.0  France
# 541908 2011-09-12 12:50:00   4.95      12680.0  France
# 541909 2011-09-12 12:50:00  18.00      12680.0  France

# %%
df.InvoiceDate.dt.dayofweek.tail()
# Out:
# 541905    0
# 541906    0
# 541907    0
# 541908    0
# 541909    0
# Name: InvoiceDate, dtype: int64

# %%
ts = pd.to_datetime('12-9-2010')

# %%
df.loc[df.InvoiceDate > ts,:]
# Out:
#        Invoice StockCode                      Description  Quantity  \
# 25281   538365     22469            HEART OF WICKER SMALL         8
# 25282   538365    84030E    ENGLISH ROSE HOT WATER BOTTLE         1
# 25283   538365     22112       CHOCOLATE HOT WATER BOTTLE         3
# 25284   538365     22835  HOT WATER BOTTLE I AM SO POORLY         5
# 25285   538365    84029E   RED WOOLLY HOTTIE WHITE HEART.         4
# ...        ...       ...                              ...       ...
# 541905  581587     22899     CHILDREN'S APRON DOLLY GIRL          6
# 541906  581587     23254    CHILDRENS CUTLERY DOLLY GIRL          4
# 541907  581587     23255  CHILDRENS CUTLERY CIRCUS PARADE         4
# 541908  581587     22138    BAKING SET 9 PIECE RETROSPOT          3
# 541909  581587      POST                          POSTAGE         1
#
#                InvoiceDate  Price  Customer ID         Country
# 25281  2010-12-12 10:11:00   1.65      17243.0  United Kingdom
# ...

# %% [markdown]
# # MATHEMATICAL OPERATIONS DATETIME

# %%
df.InvoiceDate.max()
# Out:
# Timestamp('2011-12-10 17:19:00')

# %%
df.InvoiceDate.min()
# Out:
# Timestamp('2010-01-12 08:26:00')

# %%
(df.InvoiceDate.max() -df.InvoiceDate.min()).days
# Out:
# 697

# %%
df['Year'] = df.InvoiceDate.dt.year
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  Price  Customer ID         Country  Year
# 0 2010-01-12 08:26:00   2.55      17850.0  United Kingdom  2010
# 1 2010-01-12 08:26:00   3.39      17850.0  United Kingdom  2010
# 2 2010-01-12 08:26:00   2.75      17850.0  United Kingdom  2010
# 3 2010-01-12 08:26:00   3.39      17850.0  United Kingdom  2010
# 4 2010-01-12 08:26:00   3.39      17850.0  United Kingdom  2010

# %%
df['Time'] = df.InvoiceDate.dt.time
df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1  536365     71053                  WHITE METAL LANTERN         6
# 2  536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3  536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4  536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#           InvoiceDate  Price  Customer ID         Country  Year      Time
# 0 2010-01-12 08:26:00   2.55      17850.0  United Kingdom  2010  08:26:00
# 1 2010-01-12 08:26:00   3.39      17850.0  United Kingdom  2010  08:26:00
# 2 2010-01-12 08:26:00   2.75      17850.0  United Kingdom  2010  08:26:00
# 3 2010-01-12 08:26:00   3.39      17850.0  United Kingdom  2010  08:26:00
# 4 2010-01-12 08:26:00   3.39      17850.0  United Kingdom  2010  08:26:00

# %%
# %matplotlib inline

# %%
df.Year.value_counts().sort_index().plot()
# Out:
# <AxesSubplot:>
